# %% [markdown]
# # Correlation Plots (Natural vs Incentivised)

# %%
# %%capture
import os
# If getting 'Could not find project LASR_probe_gen' get key from https://wandb.ai/authorize and paste below
os.environ["WANDB_SILENT"] = "true"
# os.environ["WANDB_API_KEY"] = ""
import wandb
wandb_token = os.getenv("WANDB_API_KEY")
wandb.login(key=wandb_token)

# %% [markdown]
# ## Final plot and variations

# %%
from probe_gen.standard_experiments import get_bar_chart_results_table_from_wandb
from probe_gen.config import BEHAVIOUR_DATASOURCE_ACTMODEL_OFFPOLICYMODEL

train_OOD = False # Do we only care about ID training data?
probe_type = ["mean", "attention_torch"][0]
done_experiments = BEHAVIOUR_DATASOURCE_ACTMODEL_OFFPOLICYMODEL

activations_model = "llama_3b"
# Get experiments into format
# [probe_type, behaviour, [ID datasource, OOD datasource], activations_model, [ID off_policy_model, OOD off_policy_model]]
train_setup = []
for behaviour in list(done_experiments.keys()):
    ds = list(done_experiments[behaviour].keys())[1:]
    off_mods = [done_experiments[behaviour][ds[0]][activations_model], done_experiments[behaviour][ds[1]][activations_model]]
    train_setup.append([probe_type, behaviour, [ds[0], ds[1]], activations_model, [off_mods[0], off_mods[1]]])
    if done_experiments[behaviour]["test_both"]:
        train_setup.append([probe_type, behaviour, [ds[1], ds[0]], activations_model, [off_mods[1], off_mods[0]]])
group_labels1 =  ['On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods1 = ['incentivised', 'prompted', 'off_policy']
test_gen_method1 = 'incentivised'
results_table1 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods1, test_gen_method1, train_OOD)
group_labels2 =  ['On-Policy Natural', 'On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods2 = ['on_policy', 'incentivised', 'prompted', 'off_policy']
test_gen_method2 = 'on_policy'
results_table2 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods2, test_gen_method2, train_OOD)

activations_model = "ministral_8b"
# Get experiments into format
# [probe_type, behaviour, [ID datasource, OOD datasource], activations_model, [ID off_policy_model, OOD off_policy_model]]
train_setup = []
for behaviour in list(done_experiments.keys()):
    ds = list(done_experiments[behaviour].keys())[1:]
    off_mods = [done_experiments[behaviour][ds[0]][activations_model], done_experiments[behaviour][ds[1]][activations_model]]
    train_setup.append([probe_type, behaviour, [ds[0], ds[1]], activations_model, [off_mods[0], off_mods[1]]])
    if done_experiments[behaviour]["test_both"]:
        train_setup.append([probe_type, behaviour, [ds[1], ds[0]], activations_model, [off_mods[1], off_mods[0]]])
group_labels3 =  ['On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods3 = ['incentivised', 'prompted', 'off_policy']
test_gen_method3 = 'incentivised'
results_table3 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods3, test_gen_method3, train_OOD)
group_labels4 =  ['On-Policy Natural', 'On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods4 = ['on_policy', 'incentivised', 'prompted', 'off_policy']
test_gen_method4 = 'on_policy'
results_table4 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods4, test_gen_method4, train_OOD)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
#  12%|█▎        | 1/8 [00:09<01:09,  9.92s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  25%|██▌       | 2/8 [00:23<01:13, 12.17s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  38%|███▊      | 3/8 [00:36<01:01, 12.26s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  50%|█████     | 4/8 [00:46<00:45, 11.44s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  62%|██████▎   | 5/8 [00:55<00:31, 10.65s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_7b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  75%|███████▌  | 6/8 [01:03<00:19,  9.70s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
#  88%|████████▊ | 7/8 [01:10<00:08,  8.92s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_7b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# 100%|██████████| 8/8 [01:16<00:00,  9.61s/it]
#   0%|          | 0/8 [00:00<?, ?it/s]
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
#  12%|█▎        | 1/8 [00:13<01:34, 13.49s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  25%|██▌       | 2/8 [00:36<01:55, 19.32s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  38%|███▊      | 3/8 [00:59<01:44, 20.82s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  50%|█████     | 4/8 [01:25<01:30, 22.68s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  62%|██████▎   | 5/8 [01:44<01:04, 21.38s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_7b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.01}
#  75%|███████▌  | 6/8 [01:56<00:36, 18.49s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
#  88%|████████▊ | 7/8 [02:08<00:16, 16.14s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'qwen_7b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'llama_3b', 'config.layer': 12, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'llama_3b', 'state': 'finished', 'config.probe/C': 0.001}
# 100%|██████████| 8/8 [02:16<00:00, 17.10s/it]
#   0%|          | 0/8 [00:00<?, ?it/s]
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  12%|█▎        | 1/8 [00:07<00:53,  7.58s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  25%|██▌       | 2/8 [00:14<00:42,  7.00s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  38%|███▊      | 3/8 [00:20<00:33,  6.61s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  50%|█████     | 4/8 [00:27<00:26,  6.68s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  62%|██████▎   | 5/8 [00:38<00:25,  8.49s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  75%|███████▌  | 6/8 [00:51<00:19,  9.80s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  88%|████████▊ | 7/8 [01:03<00:10, 10.71s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'incentivised', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# 100%|██████████| 8/8 [01:11<00:00,  8.93s/it]
#   0%|          | 0/8 [00:00<?, ?it/s]
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'refusal', 'config.train/datasource': 'rlhf', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'rlhf', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  12%|█▎        | 1/8 [00:13<01:31, 13.09s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'lists', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  25%|██▌       | 2/8 [00:23<01:08, 11.45s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'metaphors', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  38%|███▊      | 3/8 [00:31<00:49,  9.85s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'science', 'config.train/datasource': 'ultrachat', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'ultrachat', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  50%|█████     | 4/8 [00:40<00:39,  9.75s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  62%|██████▎   | 5/8 [00:56<00:35, 11.74s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'sycophancy', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 26, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  75%|███████▌  | 6/8 [01:13<00:27, 13.52s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'multichoice', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'multichoice', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
#  88%|████████▊ | 7/8 [01:21<00:11, 11.95s/it]
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'on_policy', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'incentivised', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'prompted', 'config.train/response_model': 'ministral_8b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# {'config.probe/type': 'mean', 'config.behaviour': 'authority', 'config.train/datasource': 'arguments', 'config.train/generation_method': 'off_policy', 'config.train/response_model': 'llama_3b', 'config.test/datasource': 'arguments', 'config.test/generation_method': 'on_policy', 'config.test/response_model': 'ministral_8b', 'config.layer': 14, 'config.probe/use_bias': True, 'config.probe/normalize': True, 'config.activations_model': 'ministral_8b', 'state': 'finished', 'config.probe/C': 0.001}
# 100%|██████████| 8/8 [01:32<00:00, 11.55s/it]

# %%
import matplotlib.pyplot as plt
import numpy as np

train_policy = ["prompted", "off_policy"][1]  # Which policy results to plot?

# Keep only the right data
if train_policy == "prompted":
    x1 = np.array(results_table2[-2])
    y1 = np.array(results_table1[-2])
    x2 = np.array(results_table4[-2])
    y2 = np.array(results_table3[-2])
elif train_policy == "off_policy":
    x1 = np.array(results_table2[-1])
    y1 = np.array(results_table1[-1])
    x2 = np.array(results_table4[-1])
    y2 = np.array(results_table3[-1])

# Fit lines
x_combined = np.concatenate([x1, x2])
y_combined = np.concatenate([y1, y2])
slope_combined, intercept_combined = np.polyfit(x_combined, y_combined, 1)
y_combined_pred = slope_combined * x_combined + intercept_combined

# Compute R² and R
r2_combined = 1 - np.sum((y_combined - y_combined_pred)**2) / np.sum((y_combined - np.mean(y_combined))**2)
r_combined = np.sign(slope_combined) * np.sqrt(r2_combined)

# Plot
plt.figure(figsize=(6, 6))
plt.scatter(x1, y1, label='Llama 3B', alpha=0.7)
plt.scatter(x2, y2, label='Ministral 8B', alpha=0.7)
plt.plot(
    x_combined, y_combined_pred, color='black',
    label=f'Best Fit (R={r_combined:.3f}, R²={r2_combined:.3f})'
)

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=14)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=14)
plt.title(
    f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}',
    fontsize=16
)
plt.legend()
plt.xlim(0.55, 1.0)
plt.ylim(0.55, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
# plt.savefig("correlation_plot.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_policy = ["prompted", "off_policy"][1]  # Which policy results to plot?

# Keep only the right data
if train_policy == "prompted":
    x1 = np.array(results_table2[-2])
    y1 = np.array(results_table1[-2])
    x2 = np.array(results_table4[-2])
    y2 = np.array(results_table3[-2])
elif train_policy == "off_policy":
    x1 = np.array(results_table2[-1])
    y1 = np.array(results_table1[-1])
    x2 = np.array(results_table4[-1])
    y2 = np.array(results_table3[-1])

# Combine for regression / exclusion logic
x_combined = np.concatenate([x1, x2])
y_combined = np.concatenate([y1, y2])

# Find indices of lowest x and lowest y
idx_lowest_x = np.argmin(x_combined)
idx_lowest_y = np.argmin(y_combined)
exclude_indices = {idx_lowest_x, idx_lowest_y}
mask = np.ones(len(x_combined), dtype=bool)
mask[list(exclude_indices)] = False

# Fit line (exclude outliers)
slope_combined, intercept_combined = np.polyfit(x_combined[mask], y_combined[mask], 1)
r2_combined = 1 - np.sum((y_combined[mask] - (slope_combined * x_combined[mask] + intercept_combined))**2) / \
              np.sum((y_combined[mask] - np.mean(y_combined[mask]))**2)
r_combined = np.sign(slope_combined) * np.sqrt(r2_combined)

# Prepare the fit line for plotting
x_fit_line = np.linspace(min(x_combined[mask]), max(x_combined[mask]), 100)
y_fit_line = slope_combined * x_fit_line + intercept_combined

# Plot setup
plt.figure(figsize=(6, 6))

# Helper: plot points, making lowest-x and lowest-y markers 'X'
def scatter_with_x_marker(x, y, label, color):
    for i in range(len(x)):
        global_idx = np.where(x_combined == x[i])[0][0]
        if global_idx in exclude_indices:
            plt.scatter(x[i], y[i], marker='x', s=80, color=color, label=None, alpha=0.9)
        else:
            plt.scatter(x[i], y[i], marker='o', color=color, alpha=0.7, label=None)
    plt.scatter([], [], color=color, label=label)  # dummy for legend

# Plot both datasets
scatter_with_x_marker(x1, y1, 'Llama 3B', 'C0')
scatter_with_x_marker(x2, y2, 'Ministral 8B', 'C1')

# Regression line
plt.plot(
    x_fit_line, y_fit_line,
    color='black',
    label=f'Best Fit (R={r_combined:.3f}, R²={r2_combined:.3f})'
)

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=14)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=14)
plt.title(
    f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}',
    fontsize=16
)
plt.legend()
plt.xlim(0.55, 1.0)
plt.ylim(0.55, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("correlation_plot.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_policy = ["prompted", "off_policy"][1]  # Which policy results to plot?

# Keep only the right data
if train_policy == "prompted":
    x1 = np.array(results_table2[-2])
    y1 = np.array(results_table1[-2])
    x2 = np.array(results_table4[-2])
    y2 = np.array(results_table3[-2])
    intensity1 = np.array(results_table2[0])
    intensity2 = np.array(results_table4[0])
elif train_policy == "off_policy":
    x1 = np.array(results_table2[-1])
    y1 = np.array(results_table1[-1])
    x2 = np.array(results_table4[-1])
    y2 = np.array(results_table3[-1])
    intensity1 = np.array(results_table2[0])
    intensity2 = np.array(results_table4[0])

# Normalize intensity to 0–1 range for plotting
def normalize(arr):
    arr = np.array(arr, dtype=float)
    if np.max(arr) == np.min(arr):
        return np.ones_like(arr) * 0.8  # fallback if constant
    return (arr - np.min(arr)) / (np.max(arr) - np.min(arr))

intensity1 = normalize(intensity1)
intensity2 = normalize(intensity2)

# Combine for regression / exclusion logic
x_combined = np.concatenate([x1, x2])
y_combined = np.concatenate([y1, y2])

# Find indices of lowest x and lowest y
idx_lowest_x = np.argmin(x_combined)
idx_lowest_y = np.argmin(y_combined)
exclude_indices = {idx_lowest_x, idx_lowest_y}
mask = np.ones(len(x_combined), dtype=bool)
mask[list(exclude_indices)] = False

# Fit line (exclude outliers)
slope_combined, intercept_combined = np.polyfit(x_combined[mask], y_combined[mask], 1)
r2_combined = 1 - np.sum((y_combined[mask] - (slope_combined * x_combined[mask] + intercept_combined))**2) / \
              np.sum((y_combined[mask] - np.mean(y_combined[mask]))**2)
r_combined = np.sign(slope_combined) * np.sqrt(r2_combined)

# Prepare the fit line for plotting
x_fit_line = np.linspace(min(x_combined[mask]), max(x_combined[mask]), 100)
y_fit_line = slope_combined * x_fit_line + intercept_combined

# Plot setup
plt.figure(figsize=(6, 6))

# Helper: plot points with individual brightness levels
def scatter_with_intensity(x, y, intensities, label, color):
    for i in range(len(x)):
        global_idx = np.where(x_combined == x[i])[0][0]
        marker_style = 'x' if global_idx in exclude_indices else 'o'
        plt.scatter(x[i], y[i], color=color, alpha=intensities[i], s=60, marker=marker_style)
    plt.scatter([], [], color=color, label=label)  # dummy for legend

# Plot both datasets
scatter_with_intensity(x1, y1, intensity1, 'Llama 3B', 'C0')
scatter_with_intensity(x2, y2, intensity2, 'Ministral 8B', 'C1')

# Regression line
plt.plot(
    x_fit_line, y_fit_line,
    color='black',
    label=f'Best Fit (R={r_combined:.3f}, R²={r2_combined:.3f})'
)

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(
    f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}',
    fontsize=16
)
plt.legend()
plt.xlim(0.55, 1.0)
plt.ylim(0.55, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("correlation_plot.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_policy = ["prompted", "off_policy"][1]  # Which policy results to plot?

# Keep only the right data
if train_policy == "prompted":
    x1 = np.array([results_table2[0][i] - results_table2[-2][i] for i in range(len(results_table2[0]))])
    y1 = np.array([results_table1[0][i] - results_table1[-2][i] for i in range(len(results_table1[0]))])
    x2 = np.array([results_table4[0][i] - results_table4[-2][i] for i in range(len(results_table4[0]))])
    y2 = np.array([results_table3[0][i] - results_table3[-2][i] for i in range(len(results_table3[0]))])
elif train_policy == "off_policy":
    x1 = np.array([results_table2[0][i] - results_table2[-1][i] for i in range(len(results_table2[0]))])
    y1 = np.array([results_table1[0][i] - results_table1[-1][i] for i in range(len(results_table1[0]))])
    x2 = np.array([results_table4[0][i] - results_table4[-1][i] for i in range(len(results_table4[0]))])
    y2 = np.array([results_table3[0][i] - results_table3[-1][i] for i in range(len(results_table3[0]))])

# Fit lines
x_combined = np.concatenate([x1, x2])
y_combined = np.concatenate([y1, y2])
slope_combined, intercept_combined = np.polyfit(x_combined, y_combined, 1)
y_combined_pred = slope_combined * x_combined + intercept_combined

# Compute R² and R
r2_combined = 1 - np.sum((y_combined - y_combined_pred)**2) / np.sum((y_combined - np.mean(y_combined))**2)
r_combined = np.sign(slope_combined) * np.sqrt(r2_combined)

# Plot
plt.figure(figsize=(6, 6))
plt.scatter(x1, y1, label='Llama 3B', alpha=0.7)
plt.scatter(x2, y2, label='Ministral 8B', alpha=0.7)
plt.plot(
    x_combined, y_combined_pred, color='black',
    label=f'Best Fit (R={r_combined:.3f})'#, R²={r2_combined:.3f})'
)

plt.xlabel('On-Policy Incentivised AUROC Decrease', fontsize=14)
plt.ylabel('On-Policy Natural AUROC Decrease', fontsize=14)
plt.title(
    f'Correlation of Generalisation Failures For {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"} Probes',
    fontsize=16
)
# put legend in the top right corner
plt.legend(loc='lower right')

plt.annotate(
    'Worse',
    xy=(0.4, 0.4),            # arrow tip (end point)
    xytext=(0.35, 0.35),        # text location (start point)
    textcoords='data',
    arrowprops=dict(
        arrowstyle='->',
        color='red',
        lw=2,
        shrinkA=0,
        shrinkB=0,
        mutation_scale=15
    ),
    fontsize=12,
    color='red',
    ha='center',
    va='center'
)

plt.xlim(-0.2, 0.45)
plt.ylim(-0.2, 0.45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("correlation_plot_off_policy.pdf", format="pdf", bbox_inches="tight")
# plt.savefig("correlation_plot_prompted.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Varying Probe

# %%
from probe_gen.standard_experiments import get_bar_chart_results_table_from_wandb
from probe_gen.config import BEHAVIOUR_DATASOURCE_ACTMODEL_OFFPOLICYMODEL

train_OOD = False # Do we only care about ID training data?
activations_model = ["llama_3b", "ministral_8b"][0]
done_experiments = BEHAVIOUR_DATASOURCE_ACTMODEL_OFFPOLICYMODEL

probe_type = "mean"
# Get experiments into format
# [probe_type, behaviour, [ID datasource, OOD datasource], activations_model, [ID off_policy_model, OOD off_policy_model]]
train_setup = []
for behaviour in list(done_experiments.keys()):
    ds = list(done_experiments[behaviour].keys())[1:]
    off_mods = [done_experiments[behaviour][ds[0]][activations_model], done_experiments[behaviour][ds[1]][activations_model]]
    train_setup.append([probe_type, behaviour, [ds[0], ds[1]], activations_model, [off_mods[0], off_mods[1]]])
    if done_experiments[behaviour]["test_both"]:
        train_setup.append([probe_type, behaviour, [ds[1], ds[0]], activations_model, [off_mods[1], off_mods[0]]])
group_labels1 =  ['On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods1 = ['incentivised', 'prompted', 'off_policy']
test_gen_method1 = 'incentivised'
results_table1 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods1, test_gen_method1, train_OOD)
group_labels2 =  ['On-Policy Natural', 'On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods2 = ['on_policy', 'incentivised', 'prompted', 'off_policy']
test_gen_method2 = 'on_policy'
results_table2 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods2, test_gen_method2, train_OOD)

probe_type = "attention_torch"
# Get experiments into format
# [probe_type, behaviour, [ID datasource, OOD datasource], activations_model, [ID off_policy_model, OOD off_policy_model]]
train_setup = []
for behaviour in list(done_experiments.keys()):
    ds = list(done_experiments[behaviour].keys())[1:]
    off_mods = [done_experiments[behaviour][ds[0]][activations_model], done_experiments[behaviour][ds[1]][activations_model]]
    train_setup.append([probe_type, behaviour, [ds[0], ds[1]], activations_model, [off_mods[0], off_mods[1]]])
    if done_experiments[behaviour]["test_both"]:
        train_setup.append([probe_type, behaviour, [ds[1], ds[0]], activations_model, [off_mods[1], off_mods[0]]])
group_labels3 =  ['On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods3 = ['incentivised', 'prompted', 'off_policy']
test_gen_method3 = 'incentivised'
results_table3 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods3, test_gen_method3, train_OOD)
group_labels4 =  ['On-Policy Natural', 'On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods4 = ['on_policy', 'incentivised', 'prompted', 'off_policy']
test_gen_method4 = 'on_policy'
results_table4 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods4, test_gen_method4, train_OOD)

# %%
# One row for each policy, one column for each behaviour
results_table1
# Out:
# array([[0.922096, 0.915548, 0.979532, 0.949972, 0.897628, 0.96826 ,
#         0.825648, 0.762924],
#        [0.940028, 0.921936, 0.973008, 0.937852, 0.897444, 0.552792,
#         0.755644, 0.551816],
#        [0.93076 , 0.909444, 0.958092, 0.938968, 0.875124, 0.5781  ,
#         0.781336, 0.585416]])

# %%
# One row for each policy, one column for each behaviour
results_table2
# Out:
# array([[0.908516, 0.967836, 0.931252, 0.951348, 0.9221  , 0.912616,
#         0.802116, 0.831892],
#        [0.913076, 0.948592, 0.9186  , 0.9483  , 0.908056, 0.712392,
#         0.822276, 0.688992],
#        [0.9131  , 0.964864, 0.929584, 0.948672, 0.90192 , 0.865556,
#         0.736316, 0.589416],
#        [0.90924 , 0.966144, 0.925816, 0.951204, 0.887508, 0.757776,
#         0.74794 , 0.636952]])

# %%
import matplotlib.pyplot as plt
import numpy as np

train_policy = ["prompted", "off_policy"][1] # Which policy results to plot?

# Keep only the right data
if train_policy == "prompted":
    x1 = np.array(results_table2[-2])
    y1 = np.array(results_table1[-2])
    x2 = np.array(results_table4[-2])
    y2 = np.array(results_table3[-2])
elif train_policy == "off_policy":
    x1 = np.array(results_table2[-1])
    y1 = np.array(results_table1[-1])
    x2 = np.array(results_table4[-1])
    y2 = np.array(results_table3[-1])

# Fit lines
slope1, intercept1 = np.polyfit(x1, y1, 1)
slope2, intercept2 = np.polyfit(x2, y2, 1)
slope_combined, intercept_combined = np.polyfit(np.concatenate([x1, x2]), np.concatenate([y1, y2]), 1)

y1_pred = slope1 * x1 + intercept1
y2_pred = slope2 * x2 + intercept2
y_combined_pred = slope_combined * np.concatenate([x1, x2]) + intercept_combined

# Compute R² values
r2_1 = 1 - np.sum((y1 - y1_pred)**2) / np.sum((y1 - np.mean(y1))**2)
r2_2 = 1 - np.sum((y2 - y2_pred)**2) / np.sum((y2 - np.mean(y2))**2)
r2_combined = 1 - np.sum((np.concatenate([y1, y2]) - y_combined_pred)**2) / np.sum((np.concatenate([y1, y2]) - np.mean(np.concatenate([y1, y2])))**2)

# %%
plt.figure(figsize=(7, 5))

plt.scatter(x1, y1, label='Linear', alpha=0.7)
plt.plot(x1, y1_pred, color='red', label=f'Linear Fit (R²={r2_1:.3f})')

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}', fontsize=16)
plt.legend()

plt.xlim(0.5, 1.0)
plt.ylim(0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

plt.scatter(x1, y1, label='Linear', alpha=0.7)
plt.plot(x1, y1_pred, color='red', label=f'Linear Fit (R²={r2_1:.3f})')
plt.scatter(x2, y2, label='Attention', alpha=0.7)
plt.plot(x2, y2_pred, color='green', label=f'Attention Fit (R²={r2_2:.3f})')

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}', fontsize=16)
plt.legend()

plt.xlim(0.5, 1.0)
plt.ylim(0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

plt.scatter(x1, y1, label='Linear', alpha=0.7)
plt.scatter(x2, y2, label='Attention', alpha=0.7)
plt.plot(np.concatenate([x1, x2]), y_combined_pred, color='black', label=f'Best Fit (R²={r2_combined:.3f})')

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}', fontsize=16)
plt.legend()

plt.xlim(0.5, 1.0)
plt.ylim(0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Varying Act Model

# %%
from probe_gen.standard_experiments import get_bar_chart_results_table_from_wandb
from probe_gen.config import BEHAVIOUR_DATASOURCE_ACTMODEL_OFFPOLICYMODEL

train_OOD = False # Do we only care about ID training data?
probe_type = ["mean", "attention_torch"][0]
done_experiments = BEHAVIOUR_DATASOURCE_ACTMODEL_OFFPOLICYMODEL

activations_model = "llama_3b"
# Get experiments into format
# [probe_type, behaviour, [ID datasource, OOD datasource], activations_model, [ID off_policy_model, OOD off_policy_model]]
train_setup = []
for behaviour in list(done_experiments.keys()):
    ds = list(done_experiments[behaviour].keys())[1:]
    off_mods = [done_experiments[behaviour][ds[0]][activations_model], done_experiments[behaviour][ds[1]][activations_model]]
    train_setup.append([probe_type, behaviour, [ds[0], ds[1]], activations_model, [off_mods[0], off_mods[1]]])
    if done_experiments[behaviour]["test_both"]:
        train_setup.append([probe_type, behaviour, [ds[1], ds[0]], activations_model, [off_mods[1], off_mods[0]]])
group_labels1 =  ['On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods1 = ['incentivised', 'prompted', 'off_policy']
test_gen_method1 = 'incentivised'
results_table1 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods1, test_gen_method1, train_OOD)
group_labels2 =  ['On-Policy Natural', 'On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods2 = ['on_policy', 'incentivised', 'prompted', 'off_policy']
test_gen_method2 = 'on_policy'
results_table2 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods2, test_gen_method2, train_OOD)

activations_model = "ministral_8b"
# Get experiments into format
# [probe_type, behaviour, [ID datasource, OOD datasource], activations_model, [ID off_policy_model, OOD off_policy_model]]
train_setup = []
for behaviour in list(done_experiments.keys()):
    ds = list(done_experiments[behaviour].keys())[1:]
    off_mods = [done_experiments[behaviour][ds[0]][activations_model], done_experiments[behaviour][ds[1]][activations_model]]
    train_setup.append([probe_type, behaviour, [ds[0], ds[1]], activations_model, [off_mods[0], off_mods[1]]])
    if done_experiments[behaviour]["test_both"]:
        train_setup.append([probe_type, behaviour, [ds[1], ds[0]], activations_model, [off_mods[1], off_mods[0]]])
group_labels3 =  ['On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods3 = ['incentivised', 'prompted', 'off_policy']
test_gen_method3 = 'incentivised'
results_table3 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods3, test_gen_method3, train_OOD)
group_labels4 =  ['On-Policy Natural', 'On-Policy Incentivised', 'On-Policy Prompted', 'Off-Policy']
train_gen_methods4 = ['on_policy', 'incentivised', 'prompted', 'off_policy']
test_gen_method4 = 'on_policy'
results_table4 = get_bar_chart_results_table_from_wandb(train_setup, train_gen_methods4, test_gen_method4, train_OOD)

# %%
# One row for each policy, one column for each behaviour
results_table1
# Out:
# array([[0.922096, 0.915548, 0.979532, 0.949972, 0.897628, 0.96826 ,
#         0.825648, 0.762924],
#        [0.940028, 0.921936, 0.973008, 0.937852, 0.897444, 0.552792,
#         0.755644, 0.551816],
#        [0.93076 , 0.909444, 0.958092, 0.938968, 0.875124, 0.5781  ,
#         0.781336, 0.585416]])

# %%
# One row for each policy, one column for each behaviour
results_table2
# Out:
# array([[0.908516, 0.967836, 0.931252, 0.951348, 0.9221  , 0.912616,
#         0.802116, 0.831892],
#        [0.913076, 0.948592, 0.9186  , 0.9483  , 0.908056, 0.712392,
#         0.822276, 0.688992],
#        [0.9131  , 0.964864, 0.929584, 0.948672, 0.90192 , 0.865556,
#         0.736316, 0.589416],
#        [0.90924 , 0.966144, 0.925816, 0.951204, 0.887508, 0.757776,
#         0.74794 , 0.636952]])

# %%
import matplotlib.pyplot as plt
import numpy as np

train_policy = ["prompted", "off_policy"][1] # Which policy results to plot?

# Keep only the right data
if train_policy == "prompted":
    x1 = np.array(results_table2[-2])
    y1 = np.array(results_table1[-2])
    x2 = np.array(results_table4[-2])
    y2 = np.array(results_table3[-2])
elif train_policy == "off_policy":
    x1 = np.array(results_table2[-1])
    y1 = np.array(results_table1[-1])
    x2 = np.array(results_table4[-1])
    y2 = np.array(results_table3[-1])

# Fit lines
slope1, intercept1 = np.polyfit(x1, y1, 1)
slope2, intercept2 = np.polyfit(x2, y2, 1)
slope_combined, intercept_combined = np.polyfit(np.concatenate([x1, x2]), np.concatenate([y1, y2]), 1)

y1_pred = slope1 * x1 + intercept1
y2_pred = slope2 * x2 + intercept2
y_combined_pred = slope_combined * np.concatenate([x1, x2]) + intercept_combined

# Compute R² values
r2_1 = 1 - np.sum((y1 - y1_pred)**2) / np.sum((y1 - np.mean(y1))**2)
r2_2 = 1 - np.sum((y2 - y2_pred)**2) / np.sum((y2 - np.mean(y2))**2)
r2_combined = 1 - np.sum((np.concatenate([y1, y2]) - y_combined_pred)**2) / np.sum((np.concatenate([y1, y2]) - np.mean(np.concatenate([y1, y2])))**2)

# %%
plt.figure(figsize=(7, 5))

plt.scatter(x1, y1, label='Llama', alpha=0.7)
plt.plot(x1, y1_pred, color='red', label=f'Llama Fit (R²={r2_1:.3f})')

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}', fontsize=16)
plt.legend()

plt.xlim(0.5, 1.0)
plt.ylim(0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

plt.scatter(x1, y1, label='Llama', alpha=0.7)
plt.plot(x1, y1_pred, color='red', label=f'Llama Fit (R²={r2_1:.3f})')
plt.scatter(x2, y2, label='Ministral', alpha=0.7)
plt.plot(x2, y2_pred, color='green', label=f'Ministral Fit (R²={r2_2:.3f})')

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}', fontsize=16)
plt.legend()

plt.xlim(0.5, 1.0)
plt.ylim(0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

plt.scatter(x1, y1, label='Llama', alpha=0.7)
plt.scatter(x2, y2, label='Ministral', alpha=0.7)
plt.plot(np.concatenate([x1, x2]), y_combined_pred, color='black', label=f'Best Fit (R²={r2_combined:.3f})')

plt.xlabel('On-Policy Incentivised Test AUROC', fontsize=13)
plt.ylabel('On-Policy Natural Test AUROC', fontsize=13)
plt.title(f'Correlation of Test AUROCs For Probes Trained on {"On-Policy Prompted" if train_policy == "prompted" else "Off-Policy"}', fontsize=16)
plt.legend()

plt.xlim(0.5, 1.0)
plt.ylim(0.5, 1.0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("correlation_plot.pdf", format="pdf", bbox_inches="tight")
plt.show()
