# %% [markdown]
# # Combined Probe Analysis - Loading from WandB
#
# This notebook analyzes combined probe experiments where we:
# - Train on **two datasets combined**: writingprompts + ultrachat
# - Train with all generation methods: on_policy, incentivised, prompted, off_policy
# - Test on **Shakespeare** (OOD) and **ultrachat** (ID)
#
# ## Data Source
# All results are loaded directly from **WandB** (no local JSON files needed).
#
# ## To generate new results:
# Run: `python scripts/get_probe_hyperparams_and_results_combined.py`

# %% [markdown]
# run ```python scripts/get_probe_hyperparams_and_results_combined.py```

# %%
# Visualize your new experiments:
# 1. Train WP+UC, test on UC (ID)
# 2. Train WP+Shakespeare, test on UC (OOD train → ID test)

from probe_gen.standard_experiments.behaviour_bar_plot import plot_combined_behaviour_barchart

train_setup = [
    ["mean", "sycophancy", ["arguments", "haikus"], "llama_3b", "multichoice"],
    ["mean", "sycophancy", ["arguments"], "llama_3b", "multichoice"],
    ["mean", "sycophancy", ["haikus"], "llama_3b", "multichoice"],
    ["mean", "sycophancy", ["multichoice"], "llama_3b", "multichoice"],
]

plot_combined_behaviour_barchart(
    train_setup,
    test_incentivised=False,
    add_mean_summary=False,
    title="Combined Probe Performance on Ultrachat Test Set\nID Train (WP+UC) vs OOD Train (WP+Shakes)",
    xlabel="Training Dataset Combination",
    legend_loc="upper right",
    extra_whitespace=2,
    probe_type="mean",
)
# Out:
# Fetching combined probe results from WandB...
# Querying WandB for combined probes: 100%|██████████| 6/6 [00:43<00:00,  7.27s/it]
# Fetched.
